# %%
from pathlib import Path
import pandas as pd
from data_common.pandas import GovLayers
from datetime import date

# %%
df
# Out:
#       PCON21CD                           PCON21NM    LAD21CD  \
# 0    E14000624  Central Suffolk and North Ipswich  E07000202
# 1    N06000007         Fermanagh and South Tyrone  N09000002
# 2    W07000054                           Monmouth  W06000020
# 3    E14000966            Staffordshire Moorlands  E07000195
# 4    N06000001                       Belfast East  N09000011
# ..         ...                                ...        ...
# 865  E14000752             Hornsey and Wood Green  E09000014
# 866  E14000720  Hackney North and Stoke Newington  E09000012
# 867  W07000076                         Caerphilly  W06000018
# 868  E14000636                    Chipping Barnet  E09000003
# 869  E14001039                              Wigan  E08000010
#
#                                   LAD21NM  percentage_overlap  \
# 0                                 Ipswich            0.010010
# 1    Armagh City, Banbridge and Craigavon            0.010197
# ...

# %%
df = pd.read_csv(
    Path("..", "data", "interim", "percentage_overlap_2023_councils_inc_higher.csv")
)
df
# Out:
#        PCON21CD local-authority-code  percentage_overlap
# 0     E14000530                  HAT            0.263189
# 1     E14000530                  RUH            0.736811
# 2     E14000531                  WLL            1.000000
# 3     E14000532                  TRF            1.000000
# 4     E14000533                  AMB            1.000000
# ...         ...                  ...                 ...
# 1272  E14001049                 WMCA            1.000000
# 1273  E14001050                 WMCA            1.000000
# 1274  E14001051                 WMCA            1.000000
# 1275  E14001054                 GMCA            1.000000
# 1276  E14001059                 GMCA            1.000000
#
# [1277 rows x 3 columns]

# %%
df["local-authority-code"].nunique()
# Out:
# 393
